# %%
import pandas as pd
import os

# %%
# Path to dataset
data_path = "../data/raw/cresci-2017/datasets_full.csv/"

# %%
# Load one users.csv to see the structure
genuine_users = pd.read_csv(os.path.join(data_path, "genuine_accounts.csv/genuine_accounts.csv/users.csv"))

# %%
print("Dataset shape:", genuine_users.shape)
print("\nColumn names:")
print(genuine_users.columns.tolist())
print("\nFirst few rows:")
print(genuine_users.head())
print("\nData types:")
print(genuine_users.dtypes)
